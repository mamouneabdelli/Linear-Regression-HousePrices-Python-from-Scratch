# %%
import numpy as np
def linear_model(x, w, b):
    return w * x + b

def linear_cost(x, y, w, b):
    m = len(x)
    y_pred = linear_model(x, w, b)
    return (1/(2*m)) * np.sum((y_pred - y)**2)

def linear_gradient_descent(x, y, w, b, alpha, iterations):
    m = len(x)
    for i in range(iterations):
        y_pred = linear_model(x, w, b)
        dw = (1/m) * np.sum((y_pred - y) * x)
        db = (1/m) * np.sum(y_pred - y)
        w = w - alpha * dw
        b = b - alpha * db
        print(f"Iteration {i+1}: Cost = {linear_cost(x, y, w, b):.6f}")
    return w, b

# %%
import pandas as pd
# Load dataset from csv file that downloaded from kaggle 
data = pd.read_csv("train.csv")

# Pick one feature (1D)
x = data["LotArea"].fillna(data["LotArea"].mean()).values  # 1D array

# min max scaling application 
x_scaled = (x - x.min()) / (x.max() - x.min())

# Target
y = data["SalePrice"].values
y_scaled = (y - y.min()) / (y.max() - y.min())

# %%
w = 0
b = 0
alpha = 0.1
iterations = 50


w, b = linear_gradient_descent(x_scaled, y_scaled, w, b, alpha, iterations)#1D feaature


y_pred_scaled = linear_model(x_scaled, w, b)
y_pred_real = y_pred_scaled * (y.max() - y.min()) + y.min()
# Out:
# Iteration 1: Cost = 0.022725
# Iteration 2: Cost = 0.019555
# Iteration 3: Cost = 0.016988
# Iteration 4: Cost = 0.014909
# Iteration 5: Cost = 0.013227
# Iteration 6: Cost = 0.011864
# Iteration 7: Cost = 0.010761
# Iteration 8: Cost = 0.009867
# Iteration 9: Cost = 0.009144
# Iteration 10: Cost = 0.008558
# Iteration 11: Cost = 0.008084
# Iteration 12: Cost = 0.007700
# Iteration 13: Cost = 0.007389
# Iteration 14: Cost = 0.007137
# Iteration 15: Cost = 0.006933
# Iteration 16: Cost = 0.006768
# Iteration 17: Cost = 0.006635
# Iteration 18: Cost = 0.006526
# Iteration 19: Cost = 0.006439
# Iteration 20: Cost = 0.006367
# Iteration 21: Cost = 0.006310
# Iteration 22: Cost = 0.006263
# Iteration 23: Cost = 0.006225
# Iteration 24: Cost = 0.006195
# Iteration 25: Cost = 0.006170
# Iteration 26: Cost = 0.006150
# Iteration 27: Cost = 0.006133
# Iteration 28: Cost = 0.006120
# Iteration 29: Cost = 0.006109
# Iteration 30: Cost = 0.006101
# Iteration 31: Cost = 0.006094
# Iteration 32: Cost = 0.006088
# Iteration 33: Cost = 0.006083
# Iteration 34: Cost = 0.006079
# Iteration 35: Cost = 0.006076
# Iteration 36: Cost = 0.006073
# Iteration 37: Cost = 0.006071
# Iteration 38: Cost = 0.006069
# Iteration 39: Cost = 0.006068
# Iteration 40: Cost = 0.006067
# Iteration 41: Cost = 0.006066
# Iteration 42: Cost = 0.006065
# Iteration 43: Cost = 0.006064
# Iteration 44: Cost = 0.006064
# Iteration 45: Cost = 0.006063
# Iteration 46: Cost = 0.006063
# Iteration 47: Cost = 0.006062
# Iteration 48: Cost = 0.006062
# Iteration 49: Cost = 0.006061
# Iteration 50: Cost = 0.006061

# %%
#link of data set used 
#https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=train.csv

# %%
#this cell is include how to load data set and upload all columns that contain features  and there data than drop it 
import pandas as pd

# Load dataset
data = pd.read_csv("train.csv")

# Select target column
y = data["SalePrice"]

# Select features
X = data[
    [
        "Id",
        "MSSubClass",
        "LotFrontage",
        "LotArea",
        "OverallQual",
        "OverallCond",
        "YearBuilt",
        "YearRemodAdd",
        "MasVnrArea"
    ]
]


X = X.dropna()
y = y[X.index]
